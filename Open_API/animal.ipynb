# %%
# https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15098931
# https://wonhwa.tistory.com/9

# %%
#라이브러리 import
import requests
import pprint
import json

# url 입력
url = 'https://apis.data.go.kr/1543061/abandonmentPublicSrvc/kind?serviceKey=vQdOdpBNfMUP%2BeLYJyQHgpihTD45Z6FgBkgNreos4PAk5GIB34PZ%2FY%2BOPoJSw0iQgpxg4wrHNcL3lcWk30WdcQ%3D%3D&up_kind_cd=417000&_type=json'

response = requests.get(url, verify=False)

contents = response.text

# 데이터 결과값 예쁘게 출력해주는 코드
pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(contents))

## json을 DataFrame으로 변환하기 ##

#문자열을 json으로 변경
json_ob = json.loads(contents)
print(type(json_ob)) #json타입 확인

# 필요한 내용만 꺼내기
body = json_ob['response']['body']['items']
print(body)

# pandas import
import pandas as pd
from pandas.io.json import json_normalize

# Dataframe으로 만들기
dataframe = json_normalize(body)

print(dataframe)
# Out:
# ('{\n'
#  '  "response" : {\n'
#  '    "header" : {\n'
#  '      "reqNo" : 32792781,\n'
#  '      "resultCode" : "00",\n'
#  '      "resultMsg" : "NORMAL SERVICE."\n'
#  '    },\n'
#  '    "body" : {\n'
#  '      "items" : {\n'
#  '        "item" : [ {\n'
#  '          "kindCd" : "000054",\n'
#  '          "knm" : "골든 리트리버"\n'
#  '        }, {\n'
#  '          "kindCd" : "000056",\n'
#  '          "knm" : "그레이 하운드"\n'
#  '        }, {\n'
#  '          "kindCd" : "000055",\n'
#  '          "knm" : "그레이트 덴"\n'
#  '        }, {\n'
#  '          "kindCd" : "000118",\n'
#  '          "knm" : "그레이트 피레니즈"\n'
#  '        }, {\n'
#  '          "kindCd" : "000115",\n'
#  '          "knm" : "기타"\n'
#  '        }, {\n'
#  '          "kindCd" : "000037",\n'
#  '          "knm" : "꼬똥 드 뚤레아"\n'
#  '        }, {\n'
#  '          "kindCd" : "000081",\n'
#  '          "knm" : "네오폴리탄 마스티프"\n'
#  '        }, {\n'
#  '          "kindCd" : "000204",\n'
#  '          "knm" : "노르포크 테리어"\n'
# ...

# %%
#라이브러리 import
import requests
import pprint
import json

# url 입력
url = 'https://apis.data.go.kr/1543061/abandonmentPublicSrvc/sido?serviceKey=vQdOdpBNfMUP%2BeLYJyQHgpihTD45Z6FgBkgNreos4PAk5GIB34PZ%2FY%2BOPoJSw0iQgpxg4wrHNcL3lcWk30WdcQ%3D%3D&numOfRows=17&pageNo=1&_type=json'

response = requests.get(url, verify=False)

contents = response.text

# 데이터 결과값 예쁘게 출력해주는 코드
pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(contents))

## json을 DataFrame으로 변환하기 ##

#문자열을 json으로 변경
json_ob = json.loads(contents)
print(type(json_ob)) #json타입 확인

# 필요한 내용만 꺼내기
body = json_ob['response']['body']['items']
print(body)

# pandas import
import pandas as pd
from pandas.io.json import json_normalize

# Dataframe으로 만들기
dataframe = json_normalize(body)

print(dataframe)
# Out:
# ('{\n'
#  '  "response" : {\n'
#  '    "header" : {\n'
#  '      "reqNo" : 32792783,\n'
#  '      "resultCode" : "00",\n'
#  '      "resultMsg" : "NORMAL SERVICE."\n'
#  '    },\n'
#  '    "body" : {\n'
#  '      "items" : {\n'
#  '        "item" : [ {\n'
#  '          "orgCd" : "6110000",\n'
#  '          "orgdownNm" : "서울특별시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6260000",\n'
#  '          "orgdownNm" : "부산광역시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6270000",\n'
#  '          "orgdownNm" : "대구광역시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6280000",\n'
#  '          "orgdownNm" : "인천광역시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6290000",\n'
#  '          "orgdownNm" : "광주광역시"\n'
#  '        }, {\n'
#  '          "orgCd" : "5690000",\n'
#  '          "orgdownNm" : "세종특별자치시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6300000",\n'
#  '          "orgdownNm" : "대전광역시"\n'
#  '        }, {\n'
#  '          "orgCd" : "6310000",\n'
# ...
